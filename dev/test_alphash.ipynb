# %%
from scipy.spatial import ConvexHull
import numpy as np

# %%
R = 10
points = [r*np.array((np.cos(theta), np.sin(theta))) for theta in np.linspace(0, 2*np.pi, 100) for r in np.linspace(0, 10, 20)]
l2 = [r*np.array((1.5+np.cos(theta), np.sin(theta))) for theta in np.linspace(0, 2*np.pi, 100) for r in np.linspace(0, 10, 20)]
l2.reverse()
points += l2

# %%
ch.vertices
# Out:
# array([0, 1, 2, 3], dtype=int32)

# %%
import alphashape

# %%
sh = alphashape.alphashape(points, 1/1)
sh
# Out:
# <POLYGON ((8.944 7.958, 9.461 8.326, 10 8.66, 10.559 8.96, 11.137 9.224, 11....>

# %%
for point in points:
    print(sh.boundary.buffer(2).contains(Point(point)))
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# ...

# %%
sh.boundary.distance(Point(points[201]))
# Out:
# 9.481581325471112

# %%
sh.boundary.buffer(1e-1).contains(Point(a))
# Out:
# True

# %%
sh.boundary.buffer(1e-2)
# Out:
# <POLYGON ((1 1.01, 1.001 1.01, 1.002 1.01, 1.003 1.01, 1.004 1.009, 1.005 1....>
